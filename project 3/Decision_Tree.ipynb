# %% [markdown]
# # A Decision Tree Classifier in Julia
# #### Ron Rounsifer | cs678 | GVSU

# %%
using DataFrames # hold data
using CSV # read data
using DataStructures # collection (counter)
using CPUTime # times code
using Profile # profiles code
using Distributed # for parallel processing
setprecision(300) # set the decimal precision to 300 bits
# Out:
# 300

# %% [markdown]
# ## Main Method
# #### (CPU time - 0.004 avg on 2 threads)
# 1. handles the control flow

# %%
struct Node{T<:String}
    class::T
end

function main()
    
    # all the data and info
    df = read_data()::DataFrame
    N = size(df)[1]::Int64
    num_classes = length(unique(@view df[:classification]))::Int64
    
    # Case 1:
    # if all of the conditions are the same, return that value
    if num_classes == 1
        return Node(df[1,:classification]::String)
    end
    
    #Case 2:
    # if there are no attributes, return the most common occurrence
    if (length(@view df[1,:])-1) == 0
        return Node(string(findmax(counter(df[:classification]))))
    end
    
    # Case 3:
    # if the data is normal then the root of the tree must be found
    root = find_root(df, N, num_classes)
end
# Out:
# main (generic function with 1 method)

# %% [markdown]
# ## Read Data
# Loads the data and checks if there are multiple unique values in the classification column.
#
# * <b>Case 1:</b> 1 classification, returns a Leaf of the only class.
#
# * <b>Case 2:</b> 2+ classes and 0 attributes, return a Leaf of the most common class.
#
# * <b>Case</b> 3: Normal data. Returns a dataframe

# %%
function read_data()
    df = CSV.read("./data/training.txt", delim=',', header=1)
    output_col = similar(df[:classification], nrow(df))
    return df
end
# Out:
# read_data (generic function with 1 method)

# %% [markdown]
# ## Find Root
# When a valid dataset is entered, the root of the tree must be determined.
#
# This class iterates through each class and determines which provides the tree with the most information gain.
#
# A node is created for this class and returned.

# %%
function find_root(df::DataFrame, N::Int64, n_classes::Int64)

    # array to hold class entropies.
    entropies = Vector{Float64}()
    
    # calculates entropy of each class
    for c in counter(@view df[:classification])
        print(c[1])
        print('\n')
        entropies[c[1]] = -(calc_entropy(c[2], N))
    end
    
    # calculates attribute with most information gain
    
    print(entropies)
    return
end
# Out:
# find_root (generic function with 2 methods)

# %%
function calc_entropy(in_class::Int64, N::Int64)
    p = (in_class/N)::Float64
    
    return (p * log(2,p))
end
# Out:
# calc_entropy (generic function with 2 methods)

# %% [markdown]
# ### Code Analysis
# #### Timing

# %%
@time @CPUtime main()
# Out:
# poor
# vgood
# good
# acceptable
# Dict("poor"=>0.352778,"vgood"=>0.174015,"good"=>0.154445,"acceptable"=>0.484143)elapsed CPU time: 0.193314 seconds
#   0.253620 seconds (295.45 k allocations: 14.063 MiB, 8.19% gc time)

# %% [markdown]
# #### Profiling

# %%
@profile main()
Profile.print(format=:flat)
# Out:
#  Count File                        Line Function
#    141 ./In[69]                       2 read_data()
#    141 ./In[78]                      12 main()
#      2 ./abstractarray.jl           946 _getindex
#      1 ./abstractarray.jl            57 axes
#     12 ./abstractarray.jl            75 axes
#     11 ./abstractarray.jl            93 axes1
#      4 ./abstractarray.jl           434 checkbounds
#      4 ./abstractarray.jl           449 checkbounds
#      3 ./abstractarray.jl           845 copymutable
#      2 ./abstractarray.jl           668 copyto!(::Array{Int64,1}, ::Core.Com...
#      3 ./abstractarray.jl           672 copyto!(::Array{Int64,1}, ::Core.Com...
#      5 ./abstractarray.jl           745 copyto!
#      4 ./abstractarray.jl           753 copyto!(::Core.Compiler.IndexLinear,...
#      5 ./abstractarray.jl           165 eachindex
#      6 ./abstractarray.jl           214 eachindex
#     29 ./abstractarray.jl          1866 foreach(::getfield(Core.Compiler, Sy...
#     29 ./abstractarray.jl          1866 foreach
#     50 ./abstractarray.jl          1866 foreach(::getfield(Core.Compiler, Sy...
#    729 ./abstractarray.jl          1866 foreach
#      1 ./abstractarray.jl          1866 foreach(::getfield(Core.Compiler, Sy...
#      2 ./abstractarray.jl           927 getindex
#      1 ./abstractarray.jl           863 isempty(::Array{Any,1})
#      3 ./abstractarray.jl           863 isempty
#      1 ./abstractarray.jl           100 keys
#      2 ./abstractarray.jl           249 lastindex
#      1 ./abstractarray.jl          2018 map
#     15 ./abstractarray.jl          2011 map!(::getfield(Core.Compiler, Symbo...
#      3 ./abstractarray.jl          2012 map!(::getfield(Core.Compiler, Symbo...
#      1 ./abstractarray.jl          2012 map!
#     14 ./abstractarray.jl          2012 map!(::getfield(Core.Compiler, Symbo...
#     36 ./abstractarray.jl           617 similar
#      4 ./abstractarray.jl           617 similar(::Type{Array{Any,N} where N}...
#     80 ./abstractarray.jl           617 similar
#    120 ./abstractarray.jl           618 similar
#     11 ./abstractdict.jl            509 Type
#      7 ./abstractdict.jl            512 Core.Compiler.IdDict{Int64,Int64}(::...
#      8 ./abstractdict.jl            513 Core.Compiler.IdDict{Any,Any}(::Core...
#      4 ./abstractdict.jl            675 Type
#      2 ./abstractdict.jl            680 Type
#      2 ./abstractdict.jl            634 _oidd_nextind
#     10 ./abstractdict.jl            594 get
#      1 ./abstractdict.jl            595 get
#      4 ./abstractdict.jl            646 get!
#      2 ./abstractdict.jl            598 getindex
#      7 ./abstractdict.jl             17 haskey
#      8 ./abstractdict.jl            665 in
#      2 ./abstractdict.jl            687 in
#      3 ./abstractdict.jl            637 iterate
#      3 ./abstractdict.jl            688 push!
#      9 ./abstractdict.jl            588 setindex!
#      3 ./abstractset.jl             339 mapfilter(::getfield(Core.Compiler, ...
#      8 ./abstractset.jl             340 mapfilter(::getfield(Core.Compiler, ...
#      4 ./abstractset.jl             145 setdiff
#      1 ./abstractset.jl              79 union!(::Core.Compiler.IdSet{Int64},...
#     12 ./array.jl                  1022 Type
#      2 ./array.jl                   904 _append!(::Array{Int64,1}, ::Core.Co...
#      8 ./array.jl                   506 _collect
#      6 ./array.jl                   508 _collect(::Type{Int64}, ::Core.Compi...
#      1 ./array.jl                   509 _collect(::Type{Int64}, ::Core.Compi...
#      3 ./array.jl                   510 _collect(::Type{Int64}, ::Core.Compi...
#      6 ./array.jl                   550 _collect(::Core.Compiler.UnitRange{I...
#      1 ./array.jl                   554 _collect(::Core.Compiler.UnitRange{I...
#      5 ./array.jl                   555 _collect(::Core.Compiler.UnitRange{I...
#      1 ./array.jl                   624 _collect(::Array{Core.Compiler.Basic...
#      4 ./array.jl                   821 _deleteend!
#    115 ./array.jl                   812 _growend!
#      1 ./array.jl                   767 _unsafe_bitsetindex!
#      1 ./array.jl                   812 append!
#      2 ./array.jl                   896 append!
#      2 ./array.jl                   900 append!
#      1 ./array.jl                   861 assemble_inline_todo!(::Core.Compile...
#      1 ./array.jl                   896 cfg_inline_item!(::Core.Compiler.Inl...
#      4 ./array.jl                   503 collect
#     11 ./array.jl                   503 collect(::Type{Core.LineInfoNode}, :...
#      6 ./array.jl                   503 collect
#      2 ./array.jl                   503 collect(::Type{Core.LineInfoNode}, :...
#      1 ./array.jl                   503 collect
#      8 ./array.jl                   544 collect(::Core.Compiler.Iterators.Fi...
#      8 ./array.jl                   544 collect
#      2 ./array.jl                   611 collect(::Base.Generator{Base.Iterat...
#      1 ./array.jl                   548 collect_similar
#      2 ./array.jl                   651 collect_to!(::Array{Symbol,1}, ::Bas...
#      1 ./array.jl                   655 collect_to!(::Array{Core.Compiler.Ba...
#      3 ./array.jl                   630 collect_to_with_first!
#      2 ./array.jl                   896 compute_live_ins(::Core.Compiler.CFG...
#      1 ./array.jl                   308 copy(::Array{Int32,1})
#      1 ./array.jl                   308 copy
#      1 ./array.jl                   308 copy(::Array{Int32,1})
#      9 ./array.jl                   308 copy
#     10 ./array.jl                   269 copyto!(::Array{Int64,1}, ::Int64, :...
#      7 ./array.jl                   286 copyto!
#      6 ./array.jl                   401 fill(::Bool, ::Int64)
#      5 ./array.jl                   401 fill
#      1 ./array.jl                   401 fill(::Bool, ::Int64)
#      3 ./array.jl                   401 fill
#      1 ./array.jl                   401 fill(::Bool, ::Int64)
#     17 ./array.jl                   401 fill
#     31 ./array.jl                   403 fill
#      5 ./array.jl                   372 fill!(::Array{UInt64,1}, ::UInt64)
#      4 ./array.jl                   373 fill!(::Array{UInt64,1}, ::UInt64)
#      1 ./array.jl                   375 fill!(::Array{UInt64,1}, ::UInt64)
#     11 ./array.jl                  2351 filter
#      1 ./array.jl                  1741 findfirst
#      1 ./array.jl                  1687 findnext
#      1 ./array.jl                   206 getindex(::Core.Compiler.UseRef)
#      2 ./array.jl                   207 getindex(::Core.Compiler.UseRef)
#     60 ./array.jl                   350 getindex
#     18 ./array.jl                   351 getindex
#      6 ./array.jl                   356 getindex(::Type{Any}, ::Any, ::Any, ...
#      1 ./array.jl                   356 getindex
#     14 ./array.jl                   362 getindex
#      1 ./array.jl                   362 getindex(::Type{Any})
#      7 ./array.jl                   362 getindex
#     11 ./array.jl                   729 getindex
#      3 ./array.jl                   729 getindex(::Array{Any,1}, ::Int64)
#    104 ./array.jl                   729 getindex
#      5 ./array.jl                   729 getindex(::Array{Int64,1}, ::Int64)
#     21 ./array.jl                   729 getindex
#      1 ./array.jl                   729 getindex(::Array{Core.Compiler.Basic...
#      9 ./array.jl                   729 getindex
#      1 ./array.jl                   729 getindex(::Array{Any,1}, ::Int64)
#     18 ./array.jl                   729 getindex
#      1 ./array.jl                   729 getindex(::Array{Int64,1}, ::Int64)
#     29 ./array.jl                   729 getindex
#      5 ./array.jl                   729 getindex(::Array{Int64,1}, ::Int64)
#     35 ./array.jl                   729 getindex
#      2 ./array.jl                   729 getindex(::Array{Int64,1}, ::Int64)
#     98 ./array.jl                   729 getindex
#      2 ./array.jl                   735 getindex
#      3 ./array.jl                   737 getindex
#      2 ./array.jl                   737 getindex(::Array{Any,1}, ::Core.Comp...
#      1 ./array.jl                   737 getindex
#      1 ./array.jl                   739 getindex
#      1 ./array.jl                   812 insert_node!
#      2 ./array.jl                   205 isassigned
#      1 ./array.jl                   206 isassigned
#      2 ./array.jl                   207 isassigned
#      8 ./array.jl                   705 iterate
#      1 ./array.jl                   705 iterate(::Array{Any,1})
#     70 ./array.jl                   705 iterate
#      2 ./array.jl                   705 iterate(::Array{Any,1})
#     15 ./array.jl                   705 iterate
#      1 ./array.jl                   705 iterate(::Array{Any,1}, ::Int64)
#      1 ./array.jl                   705 iterate
#      1 ./array.jl                   705 iterate(::Array{Any,1})
#      2 ./array.jl                   705 iterate
#     35 ./array.jl                   705 iterate(::Array{Any,1})
#     41 ./array.jl                   705 iterate
#      5 ./array.jl                   705 iterate(::Array{Any,1}, ::Int64)
#    162 ./array.jl                   705 iterate
#      2 ./array.jl                   199 length
#      1 ./array.jl                   199 length(::Array{Int64,1})
#     99 ./array.jl                   199 length
#      3 ./array.jl                  1066 pop!
#      1 ./array.jl                   819 popfirst!
#      3 ./array.jl                   767 push!
#     10 ./array.jl                   854 push!
#      1 ./array.jl                   854 push!(::Array{Tuple{Int64,Int64,Arra...
#      1 ./array.jl                   854 push!
#      1 ./array.jl                   854 push!(::Array{Int64,1}, ::Int64)
#     36 ./array.jl                   854 push!
#      6 ./array.jl                   855 push!
#     11 ./array.jl                   860 push!
#      4 ./array.jl                   860 push!(::Array{Any,1}, ::Any)
#      4 ./array.jl                   860 push!
#      1 ./array.jl                   861 push!(::Array{Any,1}, ::Any)
#      3 ./array.jl                   861 push!
#     45 ./array.jl                  1004 resize!
#      1 ./array.jl                  1005 resize!
#      1 ./array.jl                  1009 resize!
#      1 ./array.jl                   767 setindex!
#      1 ./array.jl                   767 setindex!(::Array{Int64,1}, ::Int64,...
#     21 ./array.jl                   767 setindex!
#      1 ./array.jl                   767 setindex!(::Array{Int64,1}, ::Int64,...
#     22 ./array.jl                   767 setindex!
#      7 ./array.jl                   316 similar
#      9 ./array.jl                   155 size
#      6 ./array.jl                  1022 sizehint!
#      1 ./array.jl                   767 ssa_substitute!
#      2 ./array.jl                   729 unsafe_bitgetindex
#      1 ./array.jl                   254 unsafe_copyto!
#      5 ./array.jl                   129 vect
#     22 ./array.jl                   449 zeros
#     22 ./array.jl                   452 zeros
#      2 ./bitarray.jl                 32 Core.Compiler.BitArray{1}(::UndefIni...
#      1 ./bitarray.jl                 34 Core.Compiler.BitArray{1}(::UndefIni...
#      3 ./bitarray.jl                 66 Type
#      1 ./bitarray.jl               1357 _collect(::Core.Compiler.UnitRange{I...
#      1 ./bitarray.jl                654 _unsafe_bitsetindex!
#      2 ./bitarray.jl                655 _unsafe_bitsetindex!
#      3 ./bitarray.jl                376 falses
#      3 ./bitarray.jl                378 falses
#      3 ./bitarray.jl                640 getindex
#      2 ./bitarray.jl                641 getindex
#      2 ./bitarray.jl                 77 size
#      2 ./bitarray.jl               1366 unsafe_bitfindnext(::Array{UInt64,1}...
#      1 ./bitarray.jl               1368 unsafe_bitfindnext(::Array{UInt64,1}...
#      2 ./bitarray.jl               1375 unsafe_bitfindnext(::Array{UInt64,1}...
#     24 ./bitset.jl                   18 Type
#      7 ./bitset.jl                   29 Type
#      9 ./bitset.jl                   69 _bits_findnext
#      1 ./bitset.jl                  113 _growend0!
#      1 ./bitset.jl                  186 _matched_map!
#      1 ./bitset.jl                  202 _matched_map!(::getfield(Core.Compil...
#      1 ./bitset.jl                   97 _setint!
#      4 ./bitset.jl                  104 _setint!
#      2 ./bitset.jl                   18 compute_live_ins(::Core.Compiler.CFG...
#      1 ./bitset.jl                   18 construct_ssa!(::Core.CodeInfo, ::Ar...
#      3 ./bitset.jl                   46 copy(::Core.Compiler.BitSet)
#      1 ./bitset.jl                   51 copy!
#      3 ./bitset.jl                   47 copymutable
#      1 ./bitset.jl                  297 delete!
#      9 ./bitset.jl                  344 iterate
#      3 ./bitset.jl                  273 push!
#      1 ./bitset.jl                  273 push!(::Core.Compiler.BitSet, ::Int64)
#      2 ./bitset.jl                  273 push!
#      1 ./bitset.jl                  320 setdiff!
#      2 ./bitset.jl                  127 union!(::Core.Compiler.BitSet, ::Cor...
#      1 ./bitset.jl                  140 union!(::Core.Compiler.BitSet, ::Cor...
#      2 ./boot.jl                    221 Expr(::Any, ::Vararg{Any,N} where N)
#     51 ./boot.jl                    221 Type
#      3 ./boot.jl                    336 Type
#      6 ./boot.jl                    337 Type
#      5 ./boot.jl                    363 Type
#      5 ./boot.jl                    373 Type
#      2 ./boot.jl                    378 Type
#    368 ./boot.jl                    402 Type
#    163 ./boot.jl                    411 Type
#     17 ./boot.jl                    416 Type
#    120 ./boot.jl                    419 Type
#    103 ./boot.jl                    421 Type
#      2 ./boot.jl                    433 Type
#      2 ./boot.jl                    732 Type
#      3 ./boot.jl                    402 _collect
#      1 ./boot.jl                    402 _similar_for
#      1 ./boot.jl                    604 checked_trunc_sint
#      1 ./boot.jl                    605 checked_trunc_sint
#  14131 ./boot.jl                    328 eval
#      1 ./boot.jl                    652 ir_inline_item!(::Core.Compiler.Incr...
#      2 ./boot.jl                    642 toInt32
#      2 ./broadcast.jl               551 _broadcast_getindex(::Base.Broadcast...
#      1 ./broadcast.jl               551 _broadcast_getindex
#      1 ./broadcast.jl               578 _broadcast_getindex_evalf
#      2 ./broadcast.jl               578 _broadcast_getindex_evalf(::typeof(S...
#    141 ./broadcast.jl               627 combine_eltypes(::Function, ::Tuple{...
#    141 ./broadcast.jl               770 copy(::Base.Broadcast.Broadcasted{Ba...
#      1 ./broadcast.jl               791 copy
#      2 ./broadcast.jl               791 copy(::Base.Broadcast.Broadcasted{Ba...
#      3 ./broadcast.jl               928 copyto_nonleaf!(::Array{LineNumberNo...
#      3 ./broadcast.jl               511 getindex
#    144 ./broadcast.jl               753 materialize(::Base.Broadcast.Broadca...
#   3637 ...stractinterpretation.jl   519 abstract_apply(::Any, ::Array{Any,1}...
#      2 ...stractinterpretation.jl   566 abstract_call(::Any, ::Array{Any,1},...
#   3638 ...stractinterpretation.jl   567 abstract_call(::Any, ::Array{Any,1},...
#     12 ...stractinterpretation.jl   577 abstract_call(::Any, ::Array{Any,1},...
#     39 ...stractinterpretation.jl   593 abstract_call(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   594 abstract_call(::Any, ::Array{Any,1},...
#     44 ...stractinterpretation.jl   595 abstract_call(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   676 abstract_call(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   726 abstract_call(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   756 abstract_call(::Any, ::Array{Any,1},...
#     91 ...stractinterpretation.jl   768 abstract_call(::Any, ::Array{Any,1},...
#     34 ...stractinterpretation.jl   769 abstract_call(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   772 abstract_call(::Any, ::Array{Any,1},...
#  25793 ...stractinterpretation.jl   776 abstract_call(::Any, ::Array{Any,1},...
#      4 ...stractinterpretation.jl    20 abstract_call_gf_by_type(::Any, ::Ar...
#      3 ...stractinterpretation.jl    21 abstract_call_gf_by_type(::Any, ::Ar...
#      5 ...stractinterpretation.jl    39 abstract_call_gf_by_type(::Any, ::Ar...
#      1 ...stractinterpretation.jl    41 abstract_call_gf_by_type(::Any, ::Ar...
#     11 ...stractinterpretation.jl    44 abstract_call_gf_by_type(::Any, ::Ar...
#    861 ...stractinterpretation.jl    49 abstract_call_gf_by_type(::Any, ::Ar...
#      3 ...stractinterpretation.jl    56 abstract_call_gf_by_type(::Any, ::Ar...
#      1 ...stractinterpretation.jl    64 abstract_call_gf_by_type(::Any, ::Ar...
#      1 ...stractinterpretation.jl    66 abstract_call_gf_by_type(::Any, ::Ar...
#      1 ...stractinterpretation.jl    68 abstract_call_gf_by_type(::Any, ::Ar...
#    652 ...stractinterpretation.jl    85 abstract_call_gf_by_type(::Any, ::Ar...
#      3 ...stractinterpretation.jl    87 abstract_call_gf_by_type(::Any, ::Ar...
#      1 ...stractinterpretation.jl    90 abstract_call_gf_by_type(::Any, ::Ar...
#      1 ...stractinterpretation.jl    98 abstract_call_gf_by_type(::Any, ::Ar...
#      5 ...stractinterpretation.jl   103 abstract_call_gf_by_type(::Any, ::Ar...
#  24189 ...stractinterpretation.jl   107 abstract_call_gf_by_type(::Any, ::Ar...
#      4 ...stractinterpretation.jl   108 abstract_call_gf_by_type(::Any, ::Ar...
#      2 ...stractinterpretation.jl   113 abstract_call_gf_by_type(::Any, ::Ar...
#      2 ...stractinterpretation.jl   122 abstract_call_gf_by_type(::Any, ::Ar...
#     18 ...stractinterpretation.jl   124 abstract_call_gf_by_type(::Any, ::Ar...
#      1 ...stractinterpretation.jl   127 abstract_call_gf_by_type(::Any, ::Ar...
#      1 ...stractinterpretation.jl   128 abstract_call_gf_by_type(::Any, ::Ar...
#     21 ...stractinterpretation.jl   130 abstract_call_gf_by_type(::Any, ::Ar...
#      2 ...stractinterpretation.jl   222 abstract_call_method(::Method, ::Any...
#      1 ...stractinterpretation.jl   227 abstract_call_method(::Method, ::Any...
#      4 ...stractinterpretation.jl   275 abstract_call_method(::Method, ::Any...
#    621 ...stractinterpretation.jl   345 abstract_call_method(::Method, ::Any...
#     22 ...stractinterpretation.jl   349 abstract_call_method(::Method, ::Any...
#      1 ...stractinterpretation.jl   146 abstract_call_method_with_const_args...
#      1 ...stractinterpretation.jl   151 abstract_call_method_with_const_args...
#      5 ...stractinterpretation.jl   152 abstract_call_method_with_const_args...
#      4 ...stractinterpretation.jl   153 abstract_call_method_with_const_args...
#      1 ...stractinterpretation.jl   155 abstract_call_method_with_const_args...
#      1 ...stractinterpretation.jl   158 abstract_call_method_with_const_args...
#      2 ...stractinterpretation.jl   162 abstract_call_method_with_const_args...
#     13 ...stractinterpretation.jl   165 abstract_call_method_with_const_args...
#      2 ...stractinterpretation.jl   169 abstract_call_method_with_const_args...
#      1 ...stractinterpretation.jl   174 abstract_call_method_with_const_args...
#     20 ...stractinterpretation.jl   191 abstract_call_method_with_const_args...
#     18 ...stractinterpretation.jl   193 abstract_call_method_with_const_args...
#     44 ...stractinterpretation.jl   194 abstract_call_method_with_const_args...
#      2 ...stractinterpretation.jl   195 abstract_call_method_with_const_args...
#      1 ...stractinterpretation.jl   196 abstract_call_method_with_const_args...
#  24044 ...stractinterpretation.jl   198 abstract_call_method_with_const_args...
#     27 ...stractinterpretation.jl   202 abstract_call_method_with_const_args...
#      5 ...stractinterpretation.jl   874 abstract_eval(::Any, ::Array{Any,1},...
#      4 ...stractinterpretation.jl   877 abstract_eval(::Any, ::Array{Any,1},...
#      9 ...stractinterpretation.jl   878 abstract_eval(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   879 abstract_eval(::Any, ::Array{Any,1},...
#     12 ...stractinterpretation.jl   881 abstract_eval(::Any, ::Array{Any,1},...
#     18 ...stractinterpretation.jl   889 abstract_eval(::Any, ::Array{Any,1},...
#  26026 ...stractinterpretation.jl   890 abstract_eval(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   980 abstract_eval(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   981 abstract_eval(::Any, ::Array{Any,1},...
#      3 ...stractinterpretation.jl   782 abstract_eval_call(::Array{Any,1}, :...
#      2 ...stractinterpretation.jl   786 abstract_eval_call(::Array{Any,1}, :...
#  26021 ...stractinterpretation.jl   805 abstract_eval_call(::Array{Any,1}, :...
#    107 ...stractinterpretation.jl   989 abstract_eval_global
#     48 ...stractinterpretation.jl   990 abstract_eval_global
#      4 ...stractinterpretation.jl   992 abstract_eval_global
#      5 ...stractinterpretation.jl   996 abstract_eval_ssavalue(::Core.SSAVal...
#      4 ...stractinterpretation.jl    16 call_result_unused
#      4 ...stractinterpretation.jl   380 precise_container_type(::Any, ::Arra...
#      2 ...stractinterpretation.jl   394 precise_container_type(::Any, ::Arra...
#     18 ...stractinterpretation.jl   398 precise_container_type(::Any, ::Arra...
#      1 ...stractinterpretation.jl   399 precise_container_type(::Any, ::Arra...
#      8 ...stractinterpretation.jl   403 precise_container_type(::Any, ::Arra...
#     10 ...stractinterpretation.jl   404 precise_container_type(::Any, ::Arra...
#      5 ...stractinterpretation.jl   535 pure_eval_call(::Any, ::Array{Any,1}...
#      6 ...stractinterpretation.jl   536 pure_eval_call(::Any, ::Array{Any,1}...
#      2 ...stractinterpretation.jl   542 pure_eval_call(::Any, ::Array{Any,1}...
#      1 ...stractinterpretation.jl   543 pure_eval_call(::Any, ::Array{Any,1}...
#     19 ...stractinterpretation.jl   544 pure_eval_call(::Any, ::Array{Any,1}...
#      2 ...stractinterpretation.jl  1021 typeinf_local(::Core.Compiler.Infere...
#      3 ...stractinterpretation.jl  1024 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1027 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1031 typeinf_local(::Core.Compiler.Infere...
#      7 ...stractinterpretation.jl  1043 typeinf_local(::Core.Compiler.Infere...
#      2 ...stractinterpretation.jl  1047 typeinf_local(::Core.Compiler.Infere...
#      2 ...stractinterpretation.jl  1048 typeinf_local(::Core.Compiler.Infere...
#      2 ...stractinterpretation.jl  1065 typeinf_local(::Core.Compiler.Infere...
#     13 ...stractinterpretation.jl  1077 typeinf_local(::Core.Compiler.Infere...
#      2 ...stractinterpretation.jl  1083 typeinf_local(::Core.Compiler.Infere...
#      5 ...stractinterpretation.jl  1085 typeinf_local(::Core.Compiler.Infere...
#   4741 ...stractinterpretation.jl  1121 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1123 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1124 typeinf_local(::Core.Compiler.Infere...
#      3 ...stractinterpretation.jl  1125 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1126 typeinf_local(::Core.Compiler.Infere...
#  21317 ...stractinterpretation.jl  1135 typeinf_local(::Core.Compiler.Infere...
#     19 ...stractinterpretation.jl  1138 typeinf_local(::Core.Compiler.Infere...
#      2 ...stractinterpretation.jl  1140 typeinf_local(::Core.Compiler.Infere...
#      6 ...stractinterpretation.jl  1159 typeinf_local(::Core.Compiler.Infere...
#     16 ...stractinterpretation.jl  1164 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1176 typeinf_local(::Core.Compiler.Infere...
#  26156 ...stractinterpretation.jl  1191 typeinf_nocycle(::Core.Compiler.Infe...
#      1 ...stractinterpretation.jl  1197 typeinf_nocycle(::Core.Compiler.Infe...
#      5 ...iler/inferenceresult.jl    12 Type
#     22 ...iler/inferenceresult.jl    17 Type
#      1 ...iler/inferenceresult.jl    18 Type
#      4 ...iler/inferenceresult.jl   148 cache_lookup(::Core.MethodInstance, ...
#      1 ...iler/inferenceresult.jl   152 cache_lookup(::Core.MethodInstance, ...
#     15 ...iler/inferenceresult.jl   153 cache_lookup(::Core.MethodInstance, ...
#     28 ...iler/inferenceresult.jl   158 cache_lookup(::Core.MethodInstance, ...
#      5 ...iler/inferenceresult.jl   166 cache_lookup(::Core.MethodInstance, ...
#     18 ...iler/inferenceresult.jl    26 is_argtype_match
#      3 ...iler/inferenceresult.jl    37 matching_cache_argtypes(::Core.Metho...
#      3 ...iler/inferenceresult.jl    39 matching_cache_argtypes(::Core.Metho...
#      1 ...iler/inferenceresult.jl    41 matching_cache_argtypes(::Core.Metho...
#      2 ...iler/inferenceresult.jl    45 matching_cache_argtypes(::Core.Metho...
#      7 ...iler/inferenceresult.jl    48 matching_cache_argtypes(::Core.Metho...
#      1 ...iler/inferenceresult.jl    53 matching_cache_argtypes(::Core.Metho...
#      2 ...iler/inferenceresult.jl    64 matching_cache_argtypes(::Core.Metho...
#     30 ...iler/inferenceresult.jl    65 matching_cache_argtypes(::Core.Metho...
#     16 ...iler/inferenceresult.jl    66 matching_cache_argtypes(::Core.Metho...
#      2 ...iler/inferenceresult.jl    67 matching_cache_argtypes(::Core.Metho...
#      2 ...iler/inferenceresult.jl    70 matching_cache_argtypes(::Core.Metho...
#      8 ...iler/inferenceresult.jl    71 matching_cache_argtypes(::Core.Metho...
#      1 ...iler/inferenceresult.jl    89 matching_cache_argtypes(::Core.Metho...
#      3 ...iler/inferenceresult.jl   103 matching_cache_argtypes(::Core.Metho...
#      1 ...iler/inferenceresult.jl   120 matching_cache_argtypes(::Core.Metho...
#      1 ...iler/inferenceresult.jl   129 matching_cache_argtypes(::Core.Metho...
#      4 ...iler/inferenceresult.jl   130 matching_cache_argtypes(::Core.Metho...
#      3 ...iler/inferenceresult.jl   131 matching_cache_argtypes(::Core.Metho...
#      3 ...iler/inferenceresult.jl   144 matching_cache_argtypes(::Core.Metho...
#      1 ...piler/inferencestate.jl    47 Core.Compiler.InferenceState(::Core....
#      1 ...piler/inferencestate.jl    51 Core.Compiler.InferenceState(::Core....
#      1 ...piler/inferencestate.jl    57 Core.Compiler.InferenceState(::Core....
#      2 ...piler/inferencestate.jl    58 Core.Compiler.InferenceState(::Core....
#      1 ...piler/inferencestate.jl    65 Core.Compiler.InferenceState(::Core....
#      1 ...piler/inferencestate.jl    68 Core.Compiler.InferenceState(::Core....
#     14 ...piler/inferencestate.jl    73 Core.Compiler.InferenceState(::Core....
#      1 ...piler/inferencestate.jl    77 Core.Compiler.InferenceState(::Core....
#      1 ...piler/inferencestate.jl    97 Core.Compiler.InferenceState(::Core....
#     29 ...piler/inferencestate.jl   117 Core.Compiler.InferenceState(::Core....
#     23 ...piler/inferencestate.jl   120 Core.Compiler.InferenceState(::Core....
#      6 ...piler/inferencestate.jl   209 add_backedge!(::Core.MethodInstance,...
#      2 ...piler/inferencestate.jl   210 add_backedge!(::Core.MethodInstance,...
#      4 ...piler/inferencestate.jl   211 add_backedge!(::Core.MethodInstance,...
#     30 ...piler/inferencestate.jl   213 add_backedge!(::Core.MethodInstance,...
#      2 ...piler/inferencestate.jl   214 add_backedge!(::Core.MethodInstance,...
#      7 ...piler/inferencestate.jl   183 record_ssa_assign(::Int64, ::Any, ::...
#     10 ...piler/inferencestate.jl   185 record_ssa_assign(::Int64, ::Any, ::...
#      1 ...piler/inferencestate.jl   189 record_ssa_assign(::Int64, ::Any, ::...
#      3 ...piler/inferencestate.jl   124 spvals_from_meth_instance(::Core.Met...
#     10 ...piler/inferencestate.jl   125 spvals_from_meth_instance(::Core.Met...
#      8 ...piler/inferencestate.jl   136 spvals_from_meth_instance(::Core.Met...
#      1 ...piler/inferencestate.jl   140 spvals_from_meth_instance(::Core.Met...
#      1 ...piler/inferencestate.jl   170 update_valid_age!
#      3 ...piler/inferencestate.jl   172 update_valid_age!
#      2 ...piler/inferencestate.jl   180 update_valid_age!
#      1 ./compiler/optimize.jl        22 Type
#      1 ./compiler/optimize.jl        26 Type
#      1 ./compiler/optimize.jl       114 add_backedge!
#      3 ./compiler/optimize.jl       115 add_backedge!
#      8 ./compiler/optimize.jl       366 inline_worthy
#      8 ./compiler/optimize.jl       138 isinlineable(::Method, ::Core.Compil...
#   7287 ./compiler/optimize.jl       164 optimize(::Core.Compiler.Optimizatio...
#      1 ./compiler/optimize.jl       165 optimize(::Core.Compiler.Optimizatio...
#      1 ./compiler/optimize.jl       178 optimize(::Core.Compiler.Optimizatio...
#      2 ./compiler/optimize.jl       203 optimize(::Core.Compiler.Optimizatio...
#    112 ./compiler/optimize.jl       210 optimize(::Core.Compiler.Optimizatio...
#      2 ./compiler/optimize.jl       217 optimize(::Core.Compiler.Optimizatio...
#     38 ./compiler/optimize.jl       218 optimize(::Core.Compiler.Optimizatio...
#     15 ./compiler/optimize.jl       222 optimize(::Core.Compiler.Optimizatio...
#      3 ./compiler/optimize.jl       239 optimize(::Core.Compiler.Optimizatio...
#      8 ./compiler/optimize.jl       246 optimize(::Core.Compiler.Optimizatio...
#      1 ./compiler/optimize.jl       249 optimize(::Core.Compiler.Optimizatio...
#      5 ./compiler/optimize.jl       390 renumber_ir_elements!
#      1 ./compiler/optimize.jl       394 renumber_ir_elements!(::Array{Any,1}...
#      1 ./compiler/optimize.jl       421 renumber_ir_elements!(::Array{Any,1}...
#      3 ./compiler/optimize.jl       427 renumber_ir_elements!(::Array{Any,1}...
#      1 ./compiler/optimize.jl       272 statement_cost(::Expr, ::Int64, ::Co...
#      1 ./compiler/optimize.jl       277 statement_cost(::Expr, ::Int64, ::Co...
#      3 ./compiler/optimize.jl       299 statement_cost(::Expr, ::Int64, ::Co...
#      1 ./compiler/optimize.jl       308 statement_cost(::Expr, ::Int64, ::Co...
#      1 ./compiler/optimize.jl       323 statement_cost(::Expr, ::Int64, ::Co...
#      1 ./compiler/optimize.jl       326 statement_cost(::Expr, ::Int64, ::Co...
#     79 ...mpiler/ssair/domtree.jl    33 (::getfield(Core.Compiler, Symbol("#...
#      9 ...mpiler/ssair/domtree.jl   171 DFS(::Core.Compiler.CFG, ::UInt64)
#      1 ...mpiler/ssair/domtree.jl   175 DFS(::Core.Compiler.CFG, ::UInt64)
#      1 ...mpiler/ssair/domtree.jl   179 DFS(::Core.Compiler.CFG, ::UInt64)
#      1 ...mpiler/ssair/domtree.jl   182 DFS(::Core.Compiler.CFG, ::UInt64)
#      4 ...mpiler/ssair/domtree.jl   183 DFS(::Core.Compiler.CFG, ::UInt64)
#      5 ...mpiler/ssair/domtree.jl   187 DFS(::Core.Compiler.CFG, ::UInt64)
#      1 ...mpiler/ssair/domtree.jl   194 DFS(::Core.Compiler.CFG, ::UInt64)
#     22 ...mpiler/ssair/domtree.jl   226 SNCA(::Core.Compiler.CFG)
#      3 ...mpiler/ssair/domtree.jl   232 SNCA(::Core.Compiler.CFG)
#      1 ...mpiler/ssair/domtree.jl   236 SNCA(::Core.Compiler.CFG)
#      7 ...mpiler/ssair/domtree.jl   242 SNCA(::Core.Compiler.CFG)
#      2 ...mpiler/ssair/domtree.jl   247 SNCA(::Core.Compiler.CFG)
#      3 ...mpiler/ssair/domtree.jl   260 SNCA(::Core.Compiler.CFG)
#      1 ...mpiler/ssair/domtree.jl   266 SNCA(::Core.Compiler.CFG)
#      1 ...mpiler/ssair/domtree.jl   272 SNCA(::Core.Compiler.CFG)
#      2 ...mpiler/ssair/domtree.jl   274 SNCA(::Core.Compiler.CFG)
#      4 ...mpiler/ssair/domtree.jl     4 Type
#      6 ...mpiler/ssair/domtree.jl     7 Type
#      3 ...mpiler/ssair/domtree.jl   164 Type
#     44 ...mpiler/ssair/domtree.jl   104 construct_domtree(::Core.Compiler.CFG)
#     12 ...mpiler/ssair/domtree.jl   107 construct_domtree(::Core.Compiler.CFG)
#      3 ...mpiler/ssair/domtree.jl   110 construct_domtree(::Core.Compiler.CFG)
#     15 ...mpiler/ssair/domtree.jl   113 construct_domtree(::Core.Compiler.CFG)
#      1 ...mpiler/ssair/domtree.jl   159 length
#      1 ...mpiler/ssair/domtree.jl   160 preorder
#      1 ...mpiler/ssair/domtree.jl   206 snca_compress!(::Array{Core.Compiler...
#      6 ...mpiler/ssair/domtree.jl   209 snca_compress!(::Array{Core.Compiler...
#      1 ...mpiler/ssair/domtree.jl   210 snca_compress!(::Array{Core.Compiler...
#      9 ...mpiler/ssair/domtree.jl    31 update_level!(::Array{Core.Compiler....
#      1 ...mpiler/ssair/domtree.jl    32 update_level!
#     66 ...mpiler/ssair/domtree.jl    32 update_level!(::Array{Core.Compiler....
#     14 ...mpiler/ssair/domtree.jl    32 update_level!
#      1 ./compiler/ssair/driver.jl    56 just_construct_ssa(::Core.CodeInfo, ...
#      2 ./compiler/ssair/driver.jl    60 just_construct_ssa(::Core.CodeInfo, ...
#      1 ./compiler/ssair/driver.jl    74 just_construct_ssa(::Core.CodeInfo, ...
#      1 ./compiler/ssair/driver.jl    77 just_construct_ssa(::Core.CodeInfo, ...
#      2 ./compiler/ssair/driver.jl    78 just_construct_ssa(::Core.CodeInfo, ...
#      2 ./compiler/ssair/driver.jl    92 just_construct_ssa(::Core.CodeInfo, ...
#      6 ./compiler/ssair/driver.jl   101 just_construct_ssa(::Core.CodeInfo, ...
#     10 ./compiler/ssair/driver.jl   102 just_construct_ssa(::Core.CodeInfo, ...
#     71 ./compiler/ssair/driver.jl   103 just_construct_ssa(::Core.CodeInfo, ...
#     18 ./compiler/ssair/driver.jl   104 just_construct_ssa(::Core.CodeInfo, ...
#      1 ./compiler/ssair/driver.jl   106 just_construct_ssa(::Core.CodeInfo, ...
#     14 ./compiler/ssair/driver.jl   107 just_construct_ssa(::Core.CodeInfo, ...
#    692 ./compiler/ssair/driver.jl   109 just_construct_ssa(::Core.CodeInfo, ...
#      2 ./compiler/ssair/driver.jl    47 normalize
#      1 ./compiler/ssair/driver.jl    27 normalize_expr
#    905 ./compiler/ssair/driver.jl   114 run_passes(::Core.CodeInfo, ::Int64,...
#    174 ./compiler/ssair/driver.jl   117 run_passes(::Core.CodeInfo, ::Int64,...
#   4141 ./compiler/ssair/driver.jl   118 run_passes(::Core.CodeInfo, ::Int64,...
#    556 ./compiler/ssair/driver.jl   120 run_passes(::Core.CodeInfo, ::Int64,...
#     56 ./compiler/ssair/driver.jl   122 run_passes(::Core.CodeInfo, ::Int64,...
#    984 ./compiler/ssair/driver.jl   123 run_passes(::Core.CodeInfo, ::Int64,...
#    286 ./compiler/ssair/driver.jl   126 run_passes(::Core.CodeInfo, ::Int64,...
#      3 ./compiler/ssair/driver.jl   128 run_passes(::Core.CodeInfo, ::Int64,...
#    181 ./compiler/ssair/driver.jl   129 run_passes(::Core.CodeInfo, ::Int64,...
#      4 ...piler/ssair/inlining.jl   161 (::getfield(Core.Compiler, Symbol("#...
#      6 ...piler/ssair/inlining.jl   167 (::getfield(Core.Compiler, Symbol("#...
#      1 ...piler/ssair/inlining.jl   928 #325
#      1 ...piler/ssair/inlining.jl    32 Type
#      3 ...piler/ssair/inlining.jl    79 Core.Compiler.CFGInliningState(::Cor...
#      8 ...piler/ssair/inlining.jl   744 Core.Compiler.UnionSplitSignature(::...
#      1 ...piler/ssair/inlining.jl   745 Core.Compiler.UnionSplitSignature(::...
#      8 ...piler/ssair/inlining.jl   563 _spec_lambda
#      1 ...piler/ssair/inlining.jl   637 analyze_method!(::Int64, ::Any, ::An...
#     30 ...piler/ssair/inlining.jl   640 analyze_method!(::Int64, ::Any, ::An...
#      2 ...piler/ssair/inlining.jl   659 analyze_method!(::Int64, ::Any, ::An...
#     94 ...piler/ssair/inlining.jl   663 analyze_method!(::Int64, ::Any, ::An...
#      1 ...piler/ssair/inlining.jl   664 analyze_method!(::Int64, ::Any, ::An...
#      1 ...piler/ssair/inlining.jl   670 analyze_method!(::Int64, ::Any, ::An...
#      3 ...piler/ssair/inlining.jl   671 analyze_method!(::Int64, ::Any, ::An...
#    112 ...piler/ssair/inlining.jl   674 analyze_method!(::Int64, ::Any, ::An...
#      3 ...piler/ssair/inlining.jl   676 analyze_method!(::Int64, ::Any, ::An...
#      4 ...piler/ssair/inlining.jl   679 analyze_method!(::Int64, ::Any, ::An...
#      2 ...piler/ssair/inlining.jl   682 analyze_method!(::Int64, ::Any, ::An...
#      1 ...piler/ssair/inlining.jl   683 analyze_method!(::Int64, ::Any, ::An...
#      4 ...piler/ssair/inlining.jl   686 analyze_method!(::Int64, ::Any, ::An...
#      2 ...piler/ssair/inlining.jl   690 analyze_method!(::Int64, ::Any, ::An...
#    160 ...piler/ssair/inlining.jl   694 analyze_method!(::Int64, ::Any, ::An...
#    139 ...piler/ssair/inlining.jl   696 analyze_method!(::Int64, ::Any, ::An...
#    538 ...piler/ssair/inlining.jl   701 analyze_method!(::Int64, ::Any, ::An...
#     19 ...piler/ssair/inlining.jl   705 analyze_method!(::Int64, ::Any, ::An...
#      2 ...piler/ssair/inlining.jl   778 assemble_inline_todo!(::Core.Compile...
#      3 ...piler/ssair/inlining.jl   780 assemble_inline_todo!(::Core.Compile...
#      1 ...piler/ssair/inlining.jl   782 assemble_inline_todo!(::Core.Compile...
#     15 ...piler/ssair/inlining.jl   783 assemble_inline_todo!(::Core.Compile...
#      6 ...piler/ssair/inlining.jl   784 assemble_inline_todo!(::Core.Compile...
#     27 ...piler/ssair/inlining.jl   786 assemble_inline_todo!(::Core.Compile...
#      2 ...piler/ssair/inlining.jl   787 assemble_inline_todo!(::Core.Compile...
#      2 ...piler/ssair/inlining.jl   789 assemble_inline_todo!(::Core.Compile...
#     13 ...piler/ssair/inlining.jl   792 assemble_inline_todo!(::Core.Compile...
#     10 ...piler/ssair/inlining.jl   795 assemble_inline_todo!(::Core.Compile...
#     13 ...piler/ssair/inlining.jl   796 assemble_inline_todo!(::Core.Compile...
#      1 ...piler/ssair/inlining.jl   797 assemble_inline_todo!(::Core.Compile...
#     14 ...piler/ssair/inlining.jl   798 assemble_inline_todo!(::Core.Compile...
#      1 ...piler/ssair/inlining.jl   803 assemble_inline_todo!(::Core.Compile...
#     40 ...piler/ssair/inlining.jl   804 assemble_inline_todo!(::Core.Compile...
#     20 ...piler/ssair/inlining.jl   810 assemble_inline_todo!(::Core.Compile...
#      2 ...piler/ssair/inlining.jl   840 assemble_inline_todo!(::Core.Compile...
#      9 ...piler/ssair/inlining.jl   847 assemble_inline_todo!(::Core.Compile...
#    117 ...piler/ssair/inlining.jl   861 assemble_inline_todo!(::Core.Compile...
#      1 ...piler/ssair/inlining.jl   868 assemble_inline_todo!(::Core.Compile...
#     24 ...piler/ssair/inlining.jl   871 assemble_inline_todo!(::Core.Compile...
#     11 ...piler/ssair/inlining.jl   888 assemble_inline_todo!(::Core.Compile...
#    975 ...piler/ssair/inlining.jl   890 assemble_inline_todo!(::Core.Compile...
#      6 ...piler/ssair/inlining.jl   891 assemble_inline_todo!(::Core.Compile...
#      3 ...piler/ssair/inlining.jl   896 assemble_inline_todo!(::Core.Compile...
#    164 ...piler/ssair/inlining.jl   898 assemble_inline_todo!(::Core.Compile...
#      5 ...piler/ssair/inlining.jl   901 assemble_inline_todo!(::Core.Compile...
#     96 ...piler/ssair/inlining.jl   904 assemble_inline_todo!(::Core.Compile...
#     20 ...piler/ssair/inlining.jl   905 assemble_inline_todo!(::Core.Compile...
#   1132 ...piler/ssair/inlining.jl   910 assemble_inline_todo!(::Core.Compile...
#      4 ...piler/ssair/inlining.jl   915 assemble_inline_todo!(::Core.Compile...
#     21 ...piler/ssair/inlining.jl   916 assemble_inline_todo!(::Core.Compile...
#     12 ...piler/ssair/inlining.jl   920 assemble_inline_todo!(::Core.Compile...
#     11 ...piler/ssair/inlining.jl   923 assemble_inline_todo!(::Core.Compile...
#      4 ...piler/ssair/inlining.jl   924 assemble_inline_todo!(::Core.Compile...
#      1 ...piler/ssair/inlining.jl   928 assemble_inline_todo!(::Core.Compile...
#      1 ...piler/ssair/inlining.jl   933 assemble_inline_todo!(::Core.Compile...
#      4 ...piler/ssair/inlining.jl   934 assemble_inline_todo!(::Core.Compile...
#      5 ...piler/ssair/inlining.jl   936 assemble_inline_todo!(::Core.Compile...
#      1 ...piler/ssair/inlining.jl   946 assemble_inline_todo!(::Core.Compile...
#      4 ...piler/ssair/inlining.jl   953 assemble_inline_todo!(::Core.Compile...
#      4 ...piler/ssair/inlining.jl   958 assemble_inline_todo!(::Core.Compile...
#      2 ...piler/ssair/inlining.jl   966 assemble_inline_todo!(::Core.Compile...
#     19 ...piler/ssair/inlining.jl   967 assemble_inline_todo!(::Core.Compile...
#      3 ...piler/ssair/inlining.jl   482 batch_inline!(::Array{Any,1}, ::Core...
#      1 ...piler/ssair/inlining.jl   485 batch_inline!(::Array{Any,1}, ::Core...
#      1 ...piler/ssair/inlining.jl   489 batch_inline!(::Array{Any,1}, ::Core...
#    116 ...piler/ssair/inlining.jl   490 batch_inline!(::Array{Any,1}, ::Core...
#      5 ...piler/ssair/inlining.jl   493 batch_inline!(::Array{Any,1}, ::Core...
#      8 ...piler/ssair/inlining.jl   500 batch_inline!(::Array{Any,1}, ::Core...
#      1 ...piler/ssair/inlining.jl   505 batch_inline!(::Array{Any,1}, ::Core...
#     16 ...piler/ssair/inlining.jl   510 batch_inline!(::Array{Any,1}, ::Core...
#      7 ...piler/ssair/inlining.jl   513 batch_inline!(::Array{Any,1}, ::Core...
#      3 ...piler/ssair/inlining.jl   515 batch_inline!(::Array{Any,1}, ::Core...
#     11 ...piler/ssair/inlining.jl   522 batch_inline!(::Array{Any,1}, ::Core...
#      2 ...piler/ssair/inlining.jl   523 batch_inline!(::Array{Any,1}, ::Core...
#     61 ...piler/ssair/inlining.jl   525 batch_inline!(::Array{Any,1}, ::Core...
#      2 ...piler/ssair/inlining.jl   528 batch_inline!(::Array{Any,1}, ::Core...
#    832 ...piler/ssair/inlining.jl   533 batch_inline!(::Array{Any,1}, ::Core...
#     59 ...piler/ssair/inlining.jl   535 batch_inline!(::Array{Any,1}, ::Core...
#     20 ...piler/ssair/inlining.jl   537 batch_inline!(::Array{Any,1}, ::Core...
#      2 ...piler/ssair/inlining.jl   539 batch_inline!(::Array{Any,1}, ::Core...
#      3 ...piler/ssair/inlining.jl   541 batch_inline!(::Array{Any,1}, ::Core...
#      3 ...piler/ssair/inlining.jl   550 batch_inline!(::Array{Any,1}, ::Core...
#     59 ...piler/ssair/inlining.jl   552 batch_inline!(::Array{Any,1}, ::Core...
#     79 ...piler/ssair/inlining.jl   556 batch_inline!(::Array{Any,1}, ::Core...
#    115 ...piler/ssair/inlining.jl   107 cfg_inline_item!
#      1 ...piler/ssair/inlining.jl   112 cfg_inline_item!(::Core.Compiler.Inl...
#      1 ...piler/ssair/inlining.jl   146 cfg_inline_item!(::Core.Compiler.Inl...
#      1 ...piler/ssair/inlining.jl   149 cfg_inline_item!(::Core.Compiler.Inl...
#     32 ...piler/ssair/inlining.jl   157 cfg_inline_item!(::Core.Compiler.Inl...
#      2 ...piler/ssair/inlining.jl   158 cfg_inline_item!(::Core.Compiler.Inl...
#      2 ...piler/ssair/inlining.jl   159 cfg_inline_item!(::Core.Compiler.Inl...
# ...
#      1 ./essentials.jl              561 length
#     57 ./essentials.jl              419 setindex!
#      1 ./essentials.jl              419 setindex!(::Array{Any,1}, ::Any, ::I...
#     39 ./essentials.jl              419 setindex!
#      4 ./essentials.jl              419 setindex!(::Array{Any,1}, ::Any, ::I...
#      4 ./essentials.jl              419 setindex!
#      1 ./essentials.jl              419 setindex!(::Array{Any,1}, ::Any, ::I...
#     23 ./essentials.jl              419 setindex!
#      1 ./essentials.jl              419 setindex!(::Array{Any,1}, ::Any, ::I...
#      2 ./essentials.jl              419 setindex!
#      1 ./essentials.jl              419 ssa_substitute_op!(::Any, ::Array{An...
#      2 ./essentials.jl              173 tail
#      2 ./essentials.jl              199 unwrap_unionall
#    560 ./event.jl                   469 (::getfield(Base, Symbol("##451#452"...
#     46 ./event.jl                   475 (::getfield(Base, Symbol("##451#452"...
#    571 ./event.jl                    62 #notify#442
#     91 ./event.jl                   129 #schedule#443(::Bool, ::Function, ::...
#    314 ./event.jl                   132 #schedule#443(::Bool, ::Function, ::...
#   1142 ./event.jl                    62 notify
#     81 ./event.jl                    67 notify(::Condition, ::Nothing, ::Boo...
#    438 ./event.jl                    68 notify(::Condition, ::Nothing, ::Boo...
#     52 ./event.jl                    70 notify(::Condition, ::Nothing, ::Boo...
#     44 ./event.jl                   240 poptask()
#    438 ./event.jl                   129 schedule
#     35 ./event.jl                   412 uv_timercb(::Ptr{Nothing})
#    571 ./event.jl                   417 uv_timercb(::Ptr{Nothing})
#    672 ./event.jl                    46 wait(::Condition)
#    628 ./event.jl                   246 wait()
#     44 ./event.jl                   253 wait()
#    560 ./event.jl                   375 wait
#     92 ./expr.jl                     36 copy(::Expr)
#    274 ./expr.jl                     37 copy(::Expr)
#    666 ./expr.jl                     60 copy_exprargs(::Array{Any,1})
#      2 ./expr.jl                     42 copy_exprs(::Any)
#    366 ./expr.jl                     43 copy_exprs(::Expr)
#      4 ./expr.jl                     45 copy_exprs(::Core.PhiNode)
#      3 ./expr.jl                     48 copy_exprs(::Core.PhiNode)
#      1 ./expr.jl                     50 copy_exprs(::Core.PhiNode)
#      8 ./generator.jl                44 iterate
#      5 ./generator.jl                47 iterate
#      1 ./indices.jl                 426 Type
#      1 ./indices.jl                 455 iterate
#     25 ./int.jl                      53 +
#      7 ./int.jl                      52 -
#      2 ./int.jl                     800 -
#     29 ./int.jl                      49 <
#      4 ./int.jl                     427 <
#      1 ./int.jl                     443 <<
#      1 ./int.jl                     450 <<
#      9 ./int.jl                     428 <=
#      1 ./int.jl                     233 rem
#      1 ./int.jl                     428 searchsortedfirst
#      5 ./int.jl                     463 ssa_substitute!
#      4 ./iterators.jl               107 Type
#      2 ./iterators.jl               429 _collect(::Core.Compiler.UnitRange{I...
#      1 ./iterators.jl               133 enumerate
#      1 ./iterators.jl               133 enumerate(::Array{Any,1})
#      5 ./iterators.jl               424 filter(::Function, ::Core.Compiler.U...
#     97 ./iterators.jl               138 iterate
#      2 ./iterators.jl               138 iterate(::Core.Compiler.Iterators.En...
#     27 ./iterators.jl               138 iterate
#     31 ./iterators.jl               139 iterate(::Core.Compiler.Iterators.En...
#      1 ./iterators.jl               139 iterate
#      2 ./iterators.jl               139 iterate(::Core.Compiler.Iterators.En...
#      1 ./iterators.jl               139 iterate
#      6 ./iterators.jl               141 iterate(::Core.Compiler.Iterators.En...
#      4 ./iterators.jl               141 iterate
#     76 ./iterators.jl               141 iterate(::Core.Compiler.Iterators.En...
#      1 ./iterators.jl               234 iterate
#      1 ./iterators.jl               427 iterate
#      7 ./iterators.jl               429 iterate
#    628 ./libuv.jl                    98 process_events
#      2 ./number.jl                    7 convert
#      2 ./operators.jl               185 !=
#     10 ./operators.jl                83 ==
#      7 ./operators.jl               155 ==(::Type, ::Type)
#     27 ./operators.jl               286 >
#      3 ./operators.jl               333 >=
#     17 ./operators.jl                83 in
#      3 ./operators.jl               949 in
#     10 ./operators.jl               950 in
#     13 ./operators.jl               954 in
#     35 ./operators.jl               813 |>(::CSV.File{false,true,Base.Generi...
#      1 ./ordering.jl                 52 lt
#     53 ./pair.jl                     12 Type
#      1 ./pair.jl                     15 Type
#     15 ./pair.jl                     50 indexed_iterate(::Core.Compiler.Pair...
#      6 ./pair.jl                     50 indexed_iterate
#     28 ./promotion.jl               403 ==
#      2 ./promotion.jl               414 axes
#      4 ./range.jl                     5 Colon
#     15 ./range.jl                    22 Colon
#     15 ./range.jl                   199 Type
#     15 ./range.jl                   250 Type
#      4 ./range.jl                   274 Type
#     15 ./range.jl                    24 _colon
#      1 ./range.jl                   601 _in_unit_range
#      1 ./range.jl                   616 getindex(::Core.Compiler.UnitRange{I...
#      8 ./range.jl                   594 iterate
#      1 ./range.jl                   594 iterate(::Core.Compiler.UnitRange{In...
#      4 ./range.jl                   595 iterate
#      1 ./range.jl                   540 length
#      7 ./range.jl                   946 reverse
#      1 ./range.jl                   470 size
#     10 ./range.jl                   205 steprange_last(::Int64, ::Int64, ::I...
#      2 ./range.jl                   209 steprange_last(::Int64, ::Int64, ::I...
#      1 ./range.jl                   211 steprange_last(::Int64, ::Int64, ::I...
#      1 ./range.jl                   214 steprange_last(::Int64, ::Int64, ::I...
#      1 ./range.jl                   226 steprange_last(::Int64, ::Int64, ::I...
#      3 ./range.jl                   279 unitrange_last
#    141 ./reflection.jl              783 _methods
#    975 ./reflection.jl              790 _methods_by_ftype
#    141 ./reflection.jl              790 _methods_by_ftype(::Any, ::Int64, ::...
#    891 ./reflection.jl              790 _methods_by_ftype
#      2 ./reflection.jl              777 _uniontypes(::Union, ::Array{Any,1})
#      1 ./reflection.jl              778 _uniontypes(::Any, ::Array{Any,1})
#      2 ./reflection.jl              453 has_free_typevars
#     15 ./reflection.jl              227 isconst
#      1 ./reflection.jl             1187 min_world
#      2 ./reflection.jl              545 typeintersect
#      1 ./reflection.jl              774 unionlen(::Union)
#      3 ./reflection.jl              779 uniontypes(::Any)
#      2 ./reflection.jl              779 uniontypes
#      1 ./reflection.jl              779 uniontypes(::Any)
#      1 ./reflection.jl              779 uniontypes
#     44 ./refpointer.jl               82 Type
#     44 ./refvalue.jl                  8 Type
#     44 ./refvalue.jl                 10 Type
#      7 ./sort.jl                    293 #searchsortedfirst#4
#      1 ./sort.jl                    694 #sort!#7
#      1 ./sort.jl                    694 #sort!#7(::Core.Compiler.Sort.QuickS...
#      2 ./sort.jl                    694 #sort!#7
#      1 ./sort.jl                    682 #sort#8
#      3 ./sort.jl                    742 #sort#8
#      2 ./sort.jl                    176 compute_basic_blocks(::Array{Any,1})
#      1 ./sort.jl                    181 compute_basic_blocks(::Array{Any,1})
#      1 ./sort.jl                    181 inflate_ir(::Core.CodeInfo, ::Core.S...
#      1 ./sort.jl                    176 searchsortedfirst
#      1 ./sort.jl                    178 searchsortedfirst
#      2 ./sort.jl                    181 searchsortedfirst
#      7 ./sort.jl                    291 searchsortedfirst
#      1 ./sort.jl                    742 sort
#      1 ./sort.jl                    539 sort!
#      1 ./sort.jl                    539 sort!(::Array{Tuple{Int64,Int64},1},...
#      2 ./sort.jl                    539 sort!
#      1 ./sort.jl                    573 sort!(::Array{Tuple{Int64,Int64},1},...
#      3 ./sort.jl                    634 sort!
#    672 ./stream.jl                   47 stream_wait(::Timer, ::Condition)
#     52 ./sysimg.jl                   18 getproperty
#    314 ./sysimg.jl                   19 setproperty!(::Task, ::Symbol, ::Not...
#  14386 ./task.jl                    259 (::getfield(IJulia, Symbol("##15#18"...
#     20 ./tuple.jl                    24 getindex
#     37 ./tuple.jl                    63 indexed_iterate
#      2 ./tuple.jl                    66 indexed_iterate
#     19 ./tuple.jl                    43 iterate
#      1 ...lia/lib/julia/sys.dylib    -1 Core.Compiler.IdDict{Any,Any}(::Core...
#      7 ...lia/lib/julia/sys.dylib    -1 compute_basic_blocks(::Array{Any,1})
#     17 ...lia/lib/julia/sys.dylib    -1 getindex(::Core.Compiler.UseRef)
#      1 ...lia/lib/julia/sys.dylib    -1 map!(::getfield(Core.Compiler, Symbo...
#      1 ...es/CSV/eWuJV/src/CSV.jl   145 #File#1(::Int64, ::Bool, ::Int64, ::...
#      2 ...es/CSV/eWuJV/src/CSV.jl   163 #File#1(::Int64, ::Bool, ::Int64, ::...
#      4 ...es/CSV/eWuJV/src/CSV.jl   165 #File#1(::Int64, ::Bool, ::Int64, ::...
#     99 ...es/CSV/eWuJV/src/CSV.jl   184 #File#1(::Int64, ::Bool, ::Int64, ::...
#    106 ...es/CSV/eWuJV/src/CSV.jl   310 #read#105(::Bool, ::Dict{Int64,Funct...
#     35 ...es/CSV/eWuJV/src/CSV.jl   315 #read#105(::Bool, ::Dict{Int64,Funct...
#      2 ...JV/src/filedetection.jl   124 datalayout(::Int64, ::Parsers.Delimi...
#      4 ...JV/src/filedetection.jl   237 rowpositions(::Base.GenericIOBuffer{...
#     35 ...CSV/eWuJV/src/tables.jl    12 getproperty(::CSV.Columns, ::Symbol)
#     99 ...JV/src/typedetection.jl   110 detect(::Array{Type,1}, ::Base.Gener...
#     35 ...Mvt/src/other/tables.jl    21 DataFrame(::CSV.File{false,true,Base...
#     35 ...Mvt/src/other/tables.jl    14 fromcolumns(::CSV.Columns)
#    112 .../4UizY/src/eventloop.jl     5 eventloop(::ZMQ.Socket)
#  14274 .../4UizY/src/eventloop.jl     8 eventloop(::ZMQ.Socket)
#  14274 .../src/execute_request.jl    67 execute_request(::ZMQ.Socket, ::IJul...
#    112 ...IJulia/4UizY/src/msg.jl    69 recv_ipython(::ZMQ.Socket)
#     31 ...ulia/4UizY/src/stdio.jl   116 send_stdio(::String)
#     15 ...ulia/4UizY/src/stdio.jl   119 send_stdio(::String)
#     46 ...ulia/4UizY/src/stdio.jl   122 send_stdout
#     15 ...ulia/4UizY/src/stdio.jl   140 send_stream(::String)
#      1 ...rs/tRRFt/src/Parsers.jl   590 Parsers.Sentinel(::Array{String,1})
#     99 ...rs/tRRFt/src/Parsers.jl   662 detecttype(::Int8, ::Base.GenericIOB...
#      4 ...rs/tRRFt/src/Parsers.jl    34 readbyte
#      1 ...sers/tRRFt/src/tries.jl    25 Parsers.Trie(::UInt8, ::Bool, ::Miss...
#      1 ...sers/tRRFt/src/tries.jl    33 Type
#      1 ...sers/tRRFt/src/tries.jl    39 Parsers.Trie(::Array{String,1}, ::In...
#      4 .../src/SoftGlobalScope.jl   124 _softscope
#      2 .../src/SoftGlobalScope.jl   144 _softscope(::Expr, ::Set{Symbol}, ::...
#      2 .../src/SoftGlobalScope.jl   152 _softscope(::Expr, ::Set{Symbol}, ::...
#      1 .../src/SoftGlobalScope.jl   154 _softscope(::Expr, ::Set{Symbol}, ::...
#    141 .../src/SoftGlobalScope.jl   194 add_linenum(::Expr, ::Int64, ::Symbol)
#    141 .../src/SoftGlobalScope.jl   187 shift_linenum
#      2 .../src/SoftGlobalScope.jl   177 softscope(::Module, ::Expr)
#    143 .../src/SoftGlobalScope.jl   217 softscope_include_string(::Module, :...
#  14131 .../src/SoftGlobalScope.jl   218 softscope_include_string(::Module, :...
#     35 ...bles/qIlOP/src/utils.jl   111 iterate(::Tables.EachColumn{CSV.Colu...
#     35 ...bles/qIlOP/src/utils.jl   112 iterate(::Tables.EachColumn{CSV.Colu...
#    112 ...s/ZMQ/ABGOx/src/comm.jl    75 _recv!(::ZMQ.Socket, ::Base.RefValue...
#    112 ...s/ZMQ/ABGOx/src/comm.jl   106 recv(::ZMQ.Socket, ::Type{String})
#    112 ...ZMQ/ABGOx/src/socket.jl    44 wait
#    112 ...ing/src/FileWatching.jl   460 #wait#1(::Bool, ::Bool, ::Function, ...
